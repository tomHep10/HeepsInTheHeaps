# %%
import sys
import os

sys.path.append(os.getcwd())

# %%
import pathGraph
import importlib

importlib.reload(pathGraph)
# Out:
# <module 'pathGraph' from 'c:\\Users\\tomhu\\Desktop\\Code\\HeepsInTheHeaps\\pathGraph.py'>

# %% [markdown]
# ## Diagonal A* Plot

# %%
pg = pathGraph.pathGraph()


pg._createAStarGraph(10, 10)
pg.aStarShortestPath((0, 0), (9, 9), "Diagonal")
pg.plotGrid()

# %% [markdown]
# ## Euclidean A* plot

# %%
eu = pathGraph.pathGraph()


eu._createAStarGraph(10, 10)
eu.aStarShortestPath((0, 0), (9, 9), "Euclidean")
eu.plotGrid()
