# %%
import sys
import os

sys.path.append(os.getcwd())

# %%
import importlib
import pathGraph

importlib.reload(pathGraph)
# Out:
# <module 'pathGraph' from 'C:\\Users\\phill\\PycharmProjects\\HeepsInTheHeaps\\pathGraph.py'>

# %% [markdown]
# ## Diagonal A* Plot

# %%
pg = pathGraph.pathGraph()


pg._createAStarGraph(100, 100)
pg.aStarShortestPath((0, 0), (99, 99), "Diagonal")
pg.plotGrid()

# %% [markdown]
# ## Euclidean A* plot

# %%
eu = pathGraph.pathGraph()


eu._createAStarGraph(10, 10)
eu.aStarShortestPath((0, 0), (9, 9), "Euclidean")
eu.plotGrid()

# %%
eu = pathGraph.pathGraph()


eu._createAStarGraph(10, 10)
eu.aStarShortestPath((0, 0), (9, 9), "Manhattan")
eu.plotGrid()
